# %%
# 模型下载
from modelscope import snapshot_download
#model_dir = snapshot_download('Qwen/Qwen2.5-7B-Instruct', cache_dir='/root/autodl-tmp/models')
model_dir = snapshot_download('Qwen/Qwen3-4B', cache_dir='/root/autodl-tmp/models')
# Out:
# Downloading Model from https://www.modelscope.cn to directory: /root/autodl-tmp/models/Qwen/Qwen3-4B
# 2025-09-03 20:37:10,207 - modelscope - INFO - Got 3 files, start to download ...
# Processing 3 items:   0%|          | 0.00/3.00 [00:00<?, ?it/s]
# Downloading [README.md]:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# Downloading [LICENSE]:   0%|          | 0.00/11.1k [00:00<?, ?B/s]
# Downloading [tokenizer_config.json]:   0%|          | 0.00/9.50k [00:00<?, ?B/s]
# 2025-09-03 20:37:10,868 - modelscope - INFO - Download model 'Qwen/Qwen3-4B' successfully.
